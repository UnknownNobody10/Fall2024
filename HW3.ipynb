# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.3.0/spark-3.3.0-bin-hadoop3.tgz
# !tar xf spark-3.3.0-bin-hadoop3.tgz
# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "spark-3.3.0-bin-hadoop3"

import findspark
findspark.init()
findspark.find()
from pyspark.sql import SQLContext, Row, SparkSession
spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext
# Out:
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <ipython-input-5-f5372f7de29d> in <cell line: 16>()
#      14 sc = spark.sparkContext
#      15 path = ("C:\\Users\\skyle\\Downloads\\assgn3_data-2-1.zip")
# ---> 16 df1 = spark.read.json(path)
#
# /content/spark-3.3.0-bin-hadoop3/python/pyspark/sql/readwriter.py in json(self, path, schema, primitivesAsString, prefersDecimal, allowComments, allowUnquotedFieldNames, allowSingleQuotes, allowNumericLeadingZero, allowBackslashEscapingAnyCharacter, mode, columnNameOfCorruptRecord, dateFormat, timestampFormat, multiLine, allowUnquotedControlChars, lineSep, samplingRatio, dropFieldIfAllNull, encoding, locale, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, allowNonNumericNumbers)
#     282         if type(path) == list:
#     283             assert self._spark._sc._jvm is not None
# ...

# %%
sc = spark.sparkContext
path = ("C:///Users/skyle/Download/assgn3_data-2-1.zip/data/*")
df1 = sc.textFile(path)
words_rdd = df1.flatMap(lambda line: line.split()).map(lambda word: word.lower()).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)
filter_word = words_rdd.filter(lambda word_count: word_count[<10])
total_word = filter_word.map(lambda word_count: word_count[1]).sum()
congress = spark.sql("SELECT word FROM total_word WHERE word="congress")
london = spark.sql("SELECT word FROM total_word WHERE word="london")
washington = spark.sql("SELECT word FROM total_word WHERE word="washington")
football = spark.sql("SELECT word FROM total_word WHERE word="football")
max_frequency = filter_word.takeOrdered(1, key=lambda word_count: -word_count[1])
difference = SELECT aggregate '2012-09-01' AND '2012-08-01'.show(%)
monsoon_frequency = filter_word.takeOrdered(1, key="monsoon" word_count: -word_count[1])
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-34-6aa64b05853f> in <cell line: 4>()
#       2 path = ("C:///Users/skyle/Download/assgn3_data-2-1.zip/data/*")
#       3 df1 = sc.textFile(path)
# ----> 4 words_rdd = df1.flatMap(lambda line: line.split()).map(lambda word: word.lower()).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)
#
# /content/spark-3.3.0-bin-hadoop3/python/pyspark/rdd.py in reduceByKey(self, func, numPartitions, partitionFunc)
#    2273         [('a', 2), ('b', 1)]
#    2274         """
# -> 2275         return self.combineByKey(lambda x: x, func, func, numPartitions, partitionFunc)
#    2276
#    2277     def reduceByKeyLocally(self: "RDD[Tuple[K, V]]", func: Callable[[V, V], V]) -> Dict[K, V]:
#
# ...

# %%
path = "file:///C:/Users/skyle/Downloads/assgn3_data-2-1.zip"
lines = sc.textFile(path)
spark.read.json(lines)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <ipython-input-12-b632279db899> in <cell line: 3>()
#       1 path = "file:///C:/Users/skyle/Downloads/assgn3_data-2-1.zip"
#       2 lines = sc.textFile(path)
# ----> 3 spark.read.json(lines)
#
# /content/spark-3.3.0-bin-hadoop3/python/pyspark/sql/readwriter.py in json(self, path, schema, primitivesAsString, prefersDecimal, allowComments, allowUnquotedFieldNames, allowSingleQuotes, allowNumericLeadingZero, allowBackslashEscapingAnyCharacter, mode, columnNameOfCorruptRecord, dateFormat, timestampFormat, multiLine, allowUnquotedControlChars, lineSep, samplingRatio, dropFieldIfAllNull, encoding, locale, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, allowNonNumericNumbers)
#     297             assert self._spark._jvm is not None
#     298             jrdd = keyed._jrdd.map(self._spark._jvm.BytesToString())
# ...
